# %% [markdown]
# # Baseline model

# %% [markdown]
# Ako baseline model sme použili regresnú neurónovú sieť, skladajúcu sa zo 4 DENSE vrstiev(16-8-4-4) s aktivačnou funkciou RELU. Po vytvorení tohto modelu sme sa rozhodli vytvoriť iný baseline model, keďže výsledky pôvodne plánovaného modelu sme vyhodnotili ako nedostačné.

# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext tensorboard

import datetime
import os
import sys
sys.path.append('..')

import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from matplotlib import pyplot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
def timestamp():
    return datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %% [markdown]
# Načítanie hodnôt z vopred pripraveného datasetu 1.

# %%
testx = np.genfromtxt('./../../data/processed/dataSet1TestX1.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet1TestY1.csv', delimiter=',')

trainx = np.genfromtxt('./../../data/processed/dataSet1TrainX1.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./../../data/processed/dataSet1TrainY1.csv', delimiter=',')

# %% [markdown]
# Načítanie hodnôt z vopred pripraveného datasetu 2.

# %%
testx = np.genfromtxt('./../../data/processed/dataSet2TestX.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet2TestY.csv', delimiter=',')

trainx = np.genfromtxt('./datasets/dataSet2TrainX.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./datasets/dataSet2TrainY.csv', delimiter=',')

# %% [markdown]
# Načítanie hodnôt z vopred pripraveného datasetu 3.

# %%
testx = np.genfromtxt('./../../data/processed/dataSet3TestX.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet3TestY.csv', delimiter=',')

trainx = np.genfromtxt('./../../data/processed/dataSet3TrainX.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./../../data/processed/dataSet3TrainY.csv', delimiter=',')

# %%
testx = np.genfromtxt('./../../data/processed/dataSet4TestX.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet4TestY.csv', delimiter=',')

trainx = np.genfromtxt('./../../data/processed/dataSet4TrainX.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./../../data/processed/dataSet4TrainY.csv', delimiter=',')

# %%
testx = np.genfromtxt('./../../data/processed/dataSet5TestX.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet5TestY.csv', delimiter=',')

trainx = np.genfromtxt('./../../data/processed/dataSet5TrainX.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./../../data/processed/dataSet5TrainY.csv', delimiter=',')

# %%
testx = np.genfromtxt('../../../data/processed/dataSet5TestXW.csv', delimiter=',')[1:]
testy = np.genfromtxt('./../../data/processed/dataSet5TestYW.csv', delimiter=',')

trainx = np.genfromtxt('./../../data/processed/dataSet5TrainXW.csv', delimiter=',')[1:]
trainy = np.genfromtxt('./../../data/processed/dataSet5TrainYW.csv', delimiter=',')

# %% [markdown]
# Prvý model s  DENSE vrstvami.

# %%
def identity_block(X,width):
    """
    Implementation of the identity block as defined in Figure 3
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    X_shortcut = X
    
    # Second component of main path (≈3 lines)
#     X = keras.layers.Dense(width, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(X)
#     X = keras.layers.Dense(width, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(X)
#     X = keras.layers.Dense(width, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(X)
#     X = keras.layers.Dense(width, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(X)   
    X = keras.layers.Dense(width, activation='relu')(X)
    X = keras.layers.Dense(width, activation='relu')(X)
    X = keras.layers.Dense(width, activation='relu')(X)
    X = keras.layers.Dense(width, activation='relu')(X)
#     X = keras.layers.Dense(width, activation='relu')(X)
    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = keras.layers.Add()([X, X_shortcut])
    X = keras.layers.Activation('relu')(X)
    
    return X

# %%
def ResNetBH(input_shape=(25), classes=6):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """

    # Define the input as a tensor with shape input_shape
    X_input = keras.Input(input_shape)
    
    # Stage 1
    X = keras.layers.Dense(256, activation='relu')(X_input)
    # Zero-Padding
    X = keras.layers.Dense(128, activation='relu')(X)


    # Stage 3 (≈4 lines)
    X = identity_block(X,128)
#     X = identity_block(X,128)
#     X = keras.layers.Dropout(0.1)(X) 
#     X = identity_block(X,128)
    X = keras.layers.Dense(64, activation='relu')(X) 
    X = identity_block(X,64)
#     X = identity_block(X,64)
#     X = keras.layers.Dropout(0.1)(X) 
#     X = identity_block(X,64)
    X = keras.layers.Dense(32, activation='relu')(X) 
    X = identity_block(X,32)
#     X = identity_block(X,32)
#     X = identity_block(X,32)

    # output layer
#     X = keras.layers.Flatten()(X)
    X = keras.layers.Dense(classes, activation='softmax', name='fc' + str(classes))(X)
    
    
    # Create model
    model = keras.models.Model(inputs = X_input, outputs = X, name='ResNetBH')

    return model

# %%
model = ResNetBH(input_shape = (64), classes = 2)

model.compile(loss='sparse_categorical_crossentropy',  
#               optimizer=keras.optimizers.SGD(lr=0.005),
              optimizer=keras.optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False),
#               optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
              metrics=['sparse_categorical_accuracy'])

tensorboard_callback = keras.callbacks.TensorBoard(
    log_dir=os.path.join("logs", timestamp()),
    histogram_freq=1)

history = model.fit(trainx, trainy,
          validation_data=(testx, testy),
          shuffle=True,
          batch_size=64,
          epochs=150,
          callbacks=[tensorboard_callback],
          verbose=1);
# Out:
# Train on 9013 samples, validate on 2253 samples
# Epoch 1/150
# 9013/9013 [==============================] - 3s 350us/sample - loss: 0.6930 - sparse_categorical_accuracy: 0.5313 - val_loss: 0.6855 - val_sparse_categorical_accuracy: 0.5579
# Epoch 2/150
# 9013/9013 [==============================] - 1s 135us/sample - loss: 0.6889 - sparse_categorical_accuracy: 0.5419 - val_loss: 0.6865 - val_sparse_categorical_accuracy: 0.5579
# Epoch 3/150
# 9013/9013 [==============================] - 1s 161us/sample - loss: 0.6874 - sparse_categorical_accuracy: 0.5402 - val_loss: 0.6909 - val_sparse_categorical_accuracy: 0.5202
# Epoch 4/150
# 9013/9013 [==============================] - 1s 138us/sample - loss: 0.6843 - sparse_categorical_accuracy: 0.5523 - val_loss: 0.6857 - val_sparse_categorical_accuracy: 0.5579
# Epoch 5/150
# 9013/9013 [==============================] - 1s 138us/sample - loss: 0.6820 - sparse_categorical_accuracy: 0.5579 - val_loss: 0.6849 - val_sparse_categorical_accuracy: 0.5566
# Epoch 6/150
# 9013/9013 [==============================] - 1s 146us/sample - loss: 0.6786 - sparse_categorical_accuracy: 0.5660 - val_loss: 0.6927 - val_sparse_categorical_accuracy: 0.5242
# Epoch 7/150
# 9013/9013 [==============================] - 1s 138us/sample - loss: 0.6707 - sparse_categorical_accuracy: 0.5823 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.5499
# Epoch 8/150
# 9013/9013 [==============================] - 1s 162us/sample - loss: 0.6593 - sparse_categorical_accuracy: 0.5960 - val_loss: 0.6951 - val_sparse_categorical_accuracy: 0.5353
# Epoch 9/150
# 9013/9013 [==============================] - 1s 139us/sample - loss: 0.6412 - sparse_categorical_accuracy: 0.6285 - val_loss: 0.7392 - val_sparse_categorical_accuracy: 0.5126
# Epoch 10/150
# 9013/9013 [==============================] - 1s 137us/sample - loss: 0.6160 - sparse_categorical_accuracy: 0.6553 - val_loss: 0.7464 - val_sparse_categorical_accuracy: 0.5255
# Epoch 11/150
# 9013/9013 [==============================] - 1s 140us/sample - loss: 0.5871 - sparse_categorical_accuracy: 0.6846 - val_loss: 0.7701 - val_sparse_categorical_accuracy: 0.5286
# Epoch 12/150
# 9013/9013 [==============================] - 1s 149us/sample - loss: 0.5454 - sparse_categorical_accuracy: 0.7192 - val_loss: 0.8279 - val_sparse_categorical_accuracy: 0.5166
# Epoch 13/150
# 9013/9013 [==============================] - 1s 154us/sample - loss: 0.4847 - sparse_categorical_accuracy: 0.7620 - val_loss: 0.8924 - val_sparse_categorical_accuracy: 0.5353
# Epoch 14/150
# 9013/9013 [==============================] - 1s 138us/sample - loss: 0.4239 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.9999 - val_sparse_categorical_accuracy: 0.5175
# Epoch 15/150
# 9013/9013 [==============================] - 1s 139us/sample - loss: 0.3645 - sparse_categorical_accuracy: 0.8377 - val_loss: 1.1495 - val_sparse_categorical_accuracy: 0.5322
# Epoch 16/150
# 9013/9013 [==============================] - 1s 148us/sample - loss: 0.3061 - sparse_categorical_accuracy: 0.8693 - val_loss: 1.2532 - val_sparse_categorical_accuracy: 0.4998
# Epoch 17/150
# 9013/9013 [==============================] - 1s 146us/sample - loss: 0.2537 - sparse_categorical_accuracy: 0.8923 - val_loss: 1.4176 - val_sparse_categorical_accuracy: 0.5051
# Epoch 18/150
# 9013/9013 [==============================] - 1s 166us/sample - loss: 0.2032 - sparse_categorical_accuracy: 0.9172 - val_loss: 1.6506 - val_sparse_categorical_accuracy: 0.5131
# Epoch 19/150
# 9013/9013 [==============================] - 1s 139us/sample - loss: 0.1706 - sparse_categorical_accuracy: 0.9340 - val_loss: 1.8643 - val_sparse_categorical_accuracy: 0.5109
# Epoch 20/150
# 9013/9013 [==============================] - 1s 150us/sample - loss: 0.1402 - sparse_categorical_accuracy: 0.9439 - val_loss: 1.9667 - val_sparse_categorical_accuracy: 0.5122
# Epoch 21/150
# 9013/9013 [==============================] - 2s 181us/sample - loss: 0.1170 - sparse_categorical_accuracy: 0.9563 - val_loss: 2.2411 - val_sparse_categorical_accuracy: 0.5126
# Epoch 22/150
# 9013/9013 [==============================] - 1s 146us/sample - loss: 0.1064 - sparse_categorical_accuracy: 0.9582 - val_loss: 2.2908 - val_sparse_categorical_accuracy: 0.5122
# Epoch 23/150
# 9013/9013 [==============================] - 1s 140us/sample - loss: 0.0917 - sparse_categorical_accuracy: 0.9654 - val_loss: 2.5184 - val_sparse_categorical_accuracy: 0.5087
# Epoch 24/150
# 9013/9013 [==============================] - 1s 152us/sample - loss: 0.0752 - sparse_categorical_accuracy: 0.9715 - val_loss: 2.2682 - val_sparse_categorical_accuracy: 0.5184
# Epoch 25/150
# 9013/9013 [==============================] - 1s 149us/sample - loss: 0.0596 - sparse_categorical_accuracy: 0.9780 - val_loss: 2.6640 - val_sparse_categorical_accuracy: 0.5135
# Epoch 26/150
# 9013/9013 [==============================] - 1s 148us/sample - loss: 0.0625 - sparse_categorical_accuracy: 0.9767 - val_loss: 2.5951 - val_sparse_categorical_accuracy: 0.5069
# Epoch 27/150
# 9013/9013 [==============================] - 1s 145us/sample - loss: 0.0520 - sparse_categorical_accuracy: 0.9809 - val_loss: 2.8327 - val_sparse_categorical_accuracy: 0.5033
# Epoch 28/150
# 9013/9013 [==============================] - 1s 143us/sample - loss: 0.0547 - sparse_categorical_accuracy: 0.9806 - val_loss: 2.8130 - val_sparse_categorical_accuracy: 0.5064
# Epoch 29/150
# 9013/9013 [==============================] - 1s 141us/sample - loss: 0.0574 - sparse_categorical_accuracy: 0.9795 - val_loss: 2.6953 - val_sparse_categorical_accuracy: 0.5002
# Epoch 30/150
# 9013/9013 [==============================] - 2s 174us/sample - loss: 0.0411 - sparse_categorical_accuracy: 0.9857 - val_loss: 2.9687 - val_sparse_categorical_accuracy: 0.5078
# Epoch 31/150
# 9013/9013 [==============================] - 2s 184us/sample - loss: 0.0495 - sparse_categorical_accuracy: 0.9830 - val_loss: 2.9847 - val_sparse_categorical_accuracy: 0.5126
# Epoch 32/150
# 9013/9013 [==============================] - 1s 157us/sample - loss: 0.0324 - sparse_categorical_accuracy: 0.9881 - val_loss: 3.5460 - val_sparse_categorical_accuracy: 0.5126
# Epoch 33/150
# 9013/9013 [==============================] - 1s 154us/sample - loss: 0.0565 - sparse_categorical_accuracy: 0.9805 - val_loss: 3.1642 - val_sparse_categorical_accuracy: 0.5144
# Epoch 34/150
# 9013/9013 [==============================] - 1s 161us/sample - loss: 0.0257 - sparse_categorical_accuracy: 0.9907 - val_loss: 3.6017 - val_sparse_categorical_accuracy: 0.4984
# Epoch 35/150
# 9013/9013 [==============================] - 1s 153us/sample - loss: 0.0335 - sparse_categorical_accuracy: 0.9886 - val_loss: 3.3426 - val_sparse_categorical_accuracy: 0.4945
# Epoch 36/150
# 9013/9013 [==============================] - 3s 321us/sample - loss: 0.0351 - sparse_categorical_accuracy: 0.9880 - val_loss: 2.8446 - val_sparse_categorical_accuracy: 0.5215
# Epoch 37/150
# 9013/9013 [==============================] - 3s 351us/sample - loss: 0.0382 - sparse_categorical_accuracy: 0.9862 - val_loss: 3.2340 - val_sparse_categorical_accuracy: 0.5051
# Epoch 38/150
# 9013/9013 [==============================] - 2s 244us/sample - loss: 0.0308 - sparse_categorical_accuracy: 0.9892 - val_loss: 3.1946 - val_sparse_categorical_accuracy: 0.5109
# Epoch 39/150
# 9013/9013 [==============================] - 2s 266us/sample - loss: 0.0405 - sparse_categorical_accuracy: 0.9870 - val_loss: 3.3737 - val_sparse_categorical_accuracy: 0.5118
# Epoch 40/150
# 9013/9013 [==============================] - 2s 190us/sample - loss: 0.0367 - sparse_categorical_accuracy: 0.9874 - val_loss: 2.8215 - val_sparse_categorical_accuracy: 0.4945
# Epoch 41/150
# 9013/9013 [==============================] - 3s 282us/sample - loss: 0.0354 - sparse_categorical_accuracy: 0.9876 - val_loss: 3.3843 - val_sparse_categorical_accuracy: 0.5038
# Epoch 42/150
# 9013/9013 [==============================] - 3s 381us/sample - loss: 0.0358 - sparse_categorical_accuracy: 0.9855 - val_loss: 3.4604 - val_sparse_categorical_accuracy: 0.4971
# Epoch 43/150
# 9013/9013 [==============================] - 3s 374us/sample - loss: 0.0350 - sparse_categorical_accuracy: 0.9870 - val_loss: 3.5332 - val_sparse_categorical_accuracy: 0.5175
# Epoch 44/150
# 9013/9013 [==============================] - 4s 400us/sample - loss: 0.0325 - sparse_categorical_accuracy: 0.9895 - val_loss: 3.1699 - val_sparse_categorical_accuracy: 0.5122
# Epoch 45/150
# 9013/9013 [==============================] - 3s 379us/sample - loss: 0.0292 - sparse_categorical_accuracy: 0.9908 - val_loss: 3.5743 - val_sparse_categorical_accuracy: 0.5029
# Epoch 46/150
# 9013/9013 [==============================] - 3s 319us/sample - loss: 0.0358 - sparse_categorical_accuracy: 0.9877 - val_loss: 3.0767 - val_sparse_categorical_accuracy: 0.5140
# Epoch 47/150
# 9013/9013 [==============================] - 3s 321us/sample - loss: 0.0289 - sparse_categorical_accuracy: 0.9901 - val_loss: 3.6559 - val_sparse_categorical_accuracy: 0.4998
# Epoch 48/150
# 9013/9013 [==============================] - 3s 373us/sample - loss: 0.0391 - sparse_categorical_accuracy: 0.9860 - val_loss: 2.8876 - val_sparse_categorical_accuracy: 0.5126
# Epoch 49/150
# 9013/9013 [==============================] - 3s 319us/sample - loss: 0.0313 - sparse_categorical_accuracy: 0.9905 - val_loss: 3.6003 - val_sparse_categorical_accuracy: 0.5100
# Epoch 50/150
# 9013/9013 [==============================] - 3s 333us/sample - loss: 0.0354 - sparse_categorical_accuracy: 0.9882 - val_loss: 2.9081 - val_sparse_categorical_accuracy: 0.5095
# Epoch 51/150
# 9013/9013 [==============================] - 3s 315us/sample - loss: 0.0282 - sparse_categorical_accuracy: 0.9905 - val_loss: 2.8711 - val_sparse_categorical_accuracy: 0.5144
# Epoch 52/150
# 9013/9013 [==============================] - 3s 372us/sample - loss: 0.0240 - sparse_categorical_accuracy: 0.9920 - val_loss: 3.3731 - val_sparse_categorical_accuracy: 0.5158
# Epoch 53/150
# 9013/9013 [==============================] - 3s 310us/sample - loss: 0.0249 - sparse_categorical_accuracy: 0.9915 - val_loss: 3.2786 - val_sparse_categorical_accuracy: 0.5135
# Epoch 54/150
# 9013/9013 [==============================] - 3s 341us/sample - loss: 0.0319 - sparse_categorical_accuracy: 0.9895 - val_loss: 3.5836 - val_sparse_categorical_accuracy: 0.4998
# Epoch 55/150
# 9013/9013 [==============================] - 3s 315us/sample - loss: 0.0313 - sparse_categorical_accuracy: 0.9890 - val_loss: 3.1910 - val_sparse_categorical_accuracy: 0.5126
# Epoch 56/150
# 9013/9013 [==============================] - 3s 321us/sample - loss: 0.0259 - sparse_categorical_accuracy: 0.9913 - val_loss: 3.3710 - val_sparse_categorical_accuracy: 0.4984
# Epoch 57/150
# 9013/9013 [==============================] - 3s 336us/sample - loss: 0.0335 - sparse_categorical_accuracy: 0.9880 - val_loss: 3.1841 - val_sparse_categorical_accuracy: 0.5135
# Epoch 58/150
# 9013/9013 [==============================] - 3s 299us/sample - loss: 0.0333 - sparse_categorical_accuracy: 0.9882 - val_loss: 3.2804 - val_sparse_categorical_accuracy: 0.5113
# Epoch 59/150
# 9013/9013 [==============================] - 3s 324us/sample - loss: 0.0279 - sparse_categorical_accuracy: 0.9911 - val_loss: 3.6892 - val_sparse_categorical_accuracy: 0.5087
# Epoch 60/150
# 9013/9013 [==============================] - 3s 319us/sample - loss: 0.0217 - sparse_categorical_accuracy: 0.9926 - val_loss: 3.0503 - val_sparse_categorical_accuracy: 0.5104
# Epoch 61/150
# 9013/9013 [==============================] - 2s 211us/sample - loss: 0.0294 - sparse_categorical_accuracy: 0.9903 - val_loss: 2.9348 - val_sparse_categorical_accuracy: 0.5135
# Epoch 62/150
# 9013/9013 [==============================] - 1s 121us/sample - loss: 0.0224 - sparse_categorical_accuracy: 0.9932 - val_loss: 3.0806 - val_sparse_categorical_accuracy: 0.5055
# Epoch 63/150
# 9013/9013 [==============================] - 1s 123us/sample - loss: 0.0280 - sparse_categorical_accuracy: 0.9905 - val_loss: 3.1667 - val_sparse_categorical_accuracy: 0.5189
# Epoch 64/150
# 9013/9013 [==============================] - 1s 121us/sample - loss: 0.0225 - sparse_categorical_accuracy: 0.9920 - val_loss: 3.6525 - val_sparse_categorical_accuracy: 0.5193
# Epoch 65/150
# 9013/9013 [==============================] - 1s 129us/sample - loss: 0.0288 - sparse_categorical_accuracy: 0.9895 - val_loss: 3.5530 - val_sparse_categorical_accuracy: 0.4940
# Epoch 66/150
# 9013/9013 [==============================] - 1s 124us/sample - loss: 0.0295 - sparse_categorical_accuracy: 0.9895 - val_loss: 3.5152 - val_sparse_categorical_accuracy: 0.5042
# Epoch 67/150
# 9013/9013 [==============================] - 1s 121us/sample - loss: 0.0273 - sparse_categorical_accuracy: 0.9915 - val_loss: 3.2173 - val_sparse_categorical_accuracy: 0.5171
# Epoch 68/150
# 9013/9013 [==============================] - 1s 123us/sample - loss: 0.0252 - sparse_categorical_accuracy: 0.9915 - val_loss: 2.8991 - val_sparse_categorical_accuracy: 0.5153
# Epoch 69/150
# 9013/9013 [==============================] - 1s 119us/sample - loss: 0.0291 - sparse_categorical_accuracy: 0.9898 - val_loss: 3.1854 - val_sparse_categorical_accuracy: 0.5095
# Epoch 70/150
# 9013/9013 [==============================] - 1s 120us/sample - loss: 0.0226 - sparse_categorical_accuracy: 0.9928 - val_loss: 3.4778 - val_sparse_categorical_accuracy: 0.5126
# Epoch 71/150
# 9013/9013 [==============================] - 1s 126us/sample - loss: 0.0362 - sparse_categorical_accuracy: 0.9882 - val_loss: 3.2600 - val_sparse_categorical_accuracy: 0.5189
# Epoch 72/150
# 9013/9013 [==============================] - 1s 122us/sample - loss: 0.0213 - sparse_categorical_accuracy: 0.9926 - val_loss: 3.3035 - val_sparse_categorical_accuracy: 0.5113
# Epoch 73/150
# 9013/9013 [==============================] - 1s 120us/sample - loss: 0.0236 - sparse_categorical_accuracy: 0.9917 - val_loss: 3.5135 - val_sparse_categorical_accuracy: 0.5060
# Epoch 74/150
# 9013/9013 [==============================] - 1s 122us/sample - loss: 0.0237 - sparse_categorical_accuracy: 0.9911 - val_loss: 3.5684 - val_sparse_categorical_accuracy: 0.5078
# Epoch 75/150
# 9013/9013 [==============================] - 1s 151us/sample - loss: 0.0131 - sparse_categorical_accuracy: 0.9959 - val_loss: 3.8737 - val_sparse_categorical_accuracy: 0.5047
# Epoch 76/150
# 9013/9013 [==============================] - 2s 216us/sample - loss: 0.0261 - sparse_categorical_accuracy: 0.9907 - val_loss: 3.0985 - val_sparse_categorical_accuracy: 0.5055
# Epoch 77/150
# 9013/9013 [==============================] - 2s 172us/sample - loss: 0.0254 - sparse_categorical_accuracy: 0.9918 - val_loss: 3.2615 - val_sparse_categorical_accuracy: 0.5011
# Epoch 78/150
# 9013/9013 [==============================] - 1s 130us/sample - loss: 0.0181 - sparse_categorical_accuracy: 0.9939 - val_loss: 4.2324 - val_sparse_categorical_accuracy: 0.5158
# Epoch 79/150
# 9013/9013 [==============================] - 1s 122us/sample - loss: 0.0317 - sparse_categorical_accuracy: 0.9900 - val_loss: 3.4377 - val_sparse_categorical_accuracy: 0.5016
# Epoch 80/150
# 9013/9013 [==============================] - 1s 127us/sample - loss: 0.0262 - sparse_categorical_accuracy: 0.9916 - val_loss: 2.9999 - val_sparse_categorical_accuracy: 0.4891
# Epoch 81/150
# 9013/9013 [==============================] - 1s 133us/sample - loss: 0.0220 - sparse_categorical_accuracy: 0.9926 - val_loss: 3.6344 - val_sparse_categorical_accuracy: 0.5038
# Epoch 82/150
# 9013/9013 [==============================] - 1s 166us/sample - loss: 0.0330 - sparse_categorical_accuracy: 0.9887 - val_loss: 2.9154 - val_sparse_categorical_accuracy: 0.5140
# Epoch 83/150
# 9013/9013 [==============================] - 1s 150us/sample - loss: 0.0207 - sparse_categorical_accuracy: 0.9936 - val_loss: 2.9920 - val_sparse_categorical_accuracy: 0.5042
# Epoch 84/150
# 9013/9013 [==============================] - 2s 212us/sample - loss: 0.0303 - sparse_categorical_accuracy: 0.9888 - val_loss: 3.2060 - val_sparse_categorical_accuracy: 0.5029
# Epoch 85/150
# 9013/9013 [==============================] - 3s 289us/sample - loss: 0.0236 - sparse_categorical_accuracy: 0.9920 - val_loss: 3.4051 - val_sparse_categorical_accuracy: 0.5113
# Epoch 86/150
# 9013/9013 [==============================] - 1s 156us/sample - loss: 0.0285 - sparse_categorical_accuracy: 0.9907 - val_loss: 3.2619 - val_sparse_categorical_accuracy: 0.5118
# Epoch 87/150
# 9013/9013 [==============================] - 2s 173us/sample - loss: 0.0213 - sparse_categorical_accuracy: 0.9939 - val_loss: 3.1801 - val_sparse_categorical_accuracy: 0.5073
# Epoch 88/150
# 9013/9013 [==============================] - 1s 154us/sample - loss: 0.0155 - sparse_categorical_accuracy: 0.9947 - val_loss: 3.4889 - val_sparse_categorical_accuracy: 0.5087
# Epoch 89/150
# 9013/9013 [==============================] - 2s 185us/sample - loss: 0.0217 - sparse_categorical_accuracy: 0.9921 - val_loss: 3.5744 - val_sparse_categorical_accuracy: 0.4967
# Epoch 90/150
# 9013/9013 [==============================] - 2s 183us/sample - loss: 0.0124 - sparse_categorical_accuracy: 0.9960 - val_loss: 4.0809 - val_sparse_categorical_accuracy: 0.5126
# Epoch 91/150
# 9013/9013 [==============================] - 2s 188us/sample - loss: 0.0253 - sparse_categorical_accuracy: 0.9919 - val_loss: 3.6975 - val_sparse_categorical_accuracy: 0.5069
# Epoch 92/150
# 9013/9013 [==============================] - 2s 196us/sample - loss: 0.0101 - sparse_categorical_accuracy: 0.9968 - val_loss: 3.9648 - val_sparse_categorical_accuracy: 0.5024
# Epoch 93/150
# 9013/9013 [==============================] - 2s 171us/sample - loss: 0.0189 - sparse_categorical_accuracy: 0.9936 - val_loss: 3.5613 - val_sparse_categorical_accuracy: 0.5144
# Epoch 94/150
# 9013/9013 [==============================] - 2s 193us/sample - loss: 0.0269 - sparse_categorical_accuracy: 0.9907 - val_loss: 3.3911 - val_sparse_categorical_accuracy: 0.5029
# Epoch 95/150
# 9013/9013 [==============================] - 1s 134us/sample - loss: 0.0276 - sparse_categorical_accuracy: 0.9906 - val_loss: 3.1570 - val_sparse_categorical_accuracy: 0.5118
# Epoch 96/150
# 9013/9013 [==============================] - 1s 157us/sample - loss: 0.0126 - sparse_categorical_accuracy: 0.9960 - val_loss: 3.9530 - val_sparse_categorical_accuracy: 0.5033
# Epoch 97/150
# 9013/9013 [==============================] - 2s 186us/sample - loss: 0.0230 - sparse_categorical_accuracy: 0.9925 - val_loss: 3.6271 - val_sparse_categorical_accuracy: 0.5087
# Epoch 98/150
# 9013/9013 [==============================] - 1s 155us/sample - loss: 0.0264 - sparse_categorical_accuracy: 0.9918 - val_loss: 3.0847 - val_sparse_categorical_accuracy: 0.5033
# Epoch 99/150
# 9013/9013 [==============================] - 1s 143us/sample - loss: 0.0231 - sparse_categorical_accuracy: 0.9921 - val_loss: 2.9973 - val_sparse_categorical_accuracy: 0.4976
# Epoch 100/150
# 9013/9013 [==============================] - 1s 155us/sample - loss: 0.0199 - sparse_categorical_accuracy: 0.9936 - val_loss: 3.4353 - val_sparse_categorical_accuracy: 0.5091
# Epoch 101/150
# 9013/9013 [==============================] - 1s 158us/sample - loss: 0.0129 - sparse_categorical_accuracy: 0.9960 - val_loss: 3.3349 - val_sparse_categorical_accuracy: 0.5011
# Epoch 102/150
# 9013/9013 [==============================] - 1s 140us/sample - loss: 0.0264 - sparse_categorical_accuracy: 0.9911 - val_loss: 3.2986 - val_sparse_categorical_accuracy: 0.4967
# Epoch 103/150
# 9013/9013 [==============================] - 2s 215us/sample - loss: 0.0187 - sparse_categorical_accuracy: 0.9937 - val_loss: 3.6199 - val_sparse_categorical_accuracy: 0.5082
# Epoch 104/150
# 9013/9013 [==============================] - 1s 123us/sample - loss: 0.0308 - sparse_categorical_accuracy: 0.9898 - val_loss: 3.8680 - val_sparse_categorical_accuracy: 0.5007
# Epoch 105/150
# 9013/9013 [==============================] - 4s 457us/sample - loss: 0.0250 - sparse_categorical_accuracy: 0.9912 - val_loss: 3.0832 - val_sparse_categorical_accuracy: 0.5135
# Epoch 106/150
# 9013/9013 [==============================] - 2s 277us/sample - loss: 0.0237 - sparse_categorical_accuracy: 0.9925 - val_loss: 3.5928 - val_sparse_categorical_accuracy: 0.5064
# Epoch 107/150
# 9013/9013 [==============================] - 2s 229us/sample - loss: 0.0146 - sparse_categorical_accuracy: 0.9950 - val_loss: 3.9838 - val_sparse_categorical_accuracy: 0.4993
# Epoch 108/150
# 9013/9013 [==============================] - 2s 277us/sample - loss: 0.0138 - sparse_categorical_accuracy: 0.9950 - val_loss: 4.0196 - val_sparse_categorical_accuracy: 0.5029
# Epoch 109/150
# 9013/9013 [==============================] - 2s 239us/sample - loss: 0.0218 - sparse_categorical_accuracy: 0.9933 - val_loss: 3.4595 - val_sparse_categorical_accuracy: 0.4931
# Epoch 110/150
# 9013/9013 [==============================] - 2s 248us/sample - loss: 0.0149 - sparse_categorical_accuracy: 0.9947 - val_loss: 3.8680 - val_sparse_categorical_accuracy: 0.5073
# Epoch 111/150
# 9013/9013 [==============================] - 2s 218us/sample - loss: 0.0177 - sparse_categorical_accuracy: 0.9948 - val_loss: 3.6534 - val_sparse_categorical_accuracy: 0.4984
# Epoch 112/150
# 9013/9013 [==============================] - 2s 223us/sample - loss: 0.0183 - sparse_categorical_accuracy: 0.9942 - val_loss: 3.8867 - val_sparse_categorical_accuracy: 0.5144
# Epoch 113/150
# 9013/9013 [==============================] - 2s 261us/sample - loss: 0.0182 - sparse_categorical_accuracy: 0.9938 - val_loss: 4.0625 - val_sparse_categorical_accuracy: 0.5193
# Epoch 114/150
# 9013/9013 [==============================] - 3s 348us/sample - loss: 0.0214 - sparse_categorical_accuracy: 0.9939 - val_loss: 4.0068 - val_sparse_categorical_accuracy: 0.5122
# Epoch 115/150
# 9013/9013 [==============================] - 3s 316us/sample - loss: 0.0152 - sparse_categorical_accuracy: 0.9945 - val_loss: 3.8319 - val_sparse_categorical_accuracy: 0.5113
# Epoch 116/150
# 9013/9013 [==============================] - 2s 214us/sample - loss: 0.0203 - sparse_categorical_accuracy: 0.9929 - val_loss: 3.6142 - val_sparse_categorical_accuracy: 0.4971
# Epoch 117/150
# 9013/9013 [==============================] - 2s 270us/sample - loss: 0.0213 - sparse_categorical_accuracy: 0.9920 - val_loss: 3.8898 - val_sparse_categorical_accuracy: 0.5095
# Epoch 118/150
# 9013/9013 [==============================] - 3s 320us/sample - loss: 0.0171 - sparse_categorical_accuracy: 0.9950 - val_loss: 3.7467 - val_sparse_categorical_accuracy: 0.5109
# Epoch 119/150
# 9013/9013 [==============================] - 2s 257us/sample - loss: 0.0188 - sparse_categorical_accuracy: 0.9940 - val_loss: 3.7810 - val_sparse_categorical_accuracy: 0.5144
# Epoch 120/150
# 9013/9013 [==============================] - 3s 283us/sample - loss: 0.0150 - sparse_categorical_accuracy: 0.9945 - val_loss: 3.2578 - val_sparse_categorical_accuracy: 0.5038
# Epoch 121/150
# 9013/9013 [==============================] - 2s 206us/sample - loss: 0.0182 - sparse_categorical_accuracy: 0.9939 - val_loss: 4.3279 - val_sparse_categorical_accuracy: 0.5122
# Epoch 122/150
# 9013/9013 [==============================] - 2s 206us/sample - loss: 0.0108 - sparse_categorical_accuracy: 0.9955 - val_loss: 4.1687 - val_sparse_categorical_accuracy: 0.5047
# Epoch 123/150
# 9013/9013 [==============================] - 2s 254us/sample - loss: 0.0264 - sparse_categorical_accuracy: 0.9909 - val_loss: 3.2689 - val_sparse_categorical_accuracy: 0.5126
# Epoch 124/150
# 9013/9013 [==============================] - 2s 210us/sample - loss: 0.0112 - sparse_categorical_accuracy: 0.9967 - val_loss: 4.1963 - val_sparse_categorical_accuracy: 0.5011
# Epoch 125/150
# 9013/9013 [==============================] - 2s 218us/sample - loss: 0.0261 - sparse_categorical_accuracy: 0.9912 - val_loss: 3.1177 - val_sparse_categorical_accuracy: 0.5055
# Epoch 126/150
# 9013/9013 [==============================] - 2s 248us/sample - loss: 0.0171 - sparse_categorical_accuracy: 0.9941 - val_loss: 3.7913 - val_sparse_categorical_accuracy: 0.5060
# Epoch 127/150
# 9013/9013 [==============================] - 2s 211us/sample - loss: 0.0179 - sparse_categorical_accuracy: 0.9945 - val_loss: 3.7981 - val_sparse_categorical_accuracy: 0.4896
# Epoch 128/150
# 9013/9013 [==============================] - 2s 214us/sample - loss: 0.0123 - sparse_categorical_accuracy: 0.9961 - val_loss: 3.8727 - val_sparse_categorical_accuracy: 0.4900
# Epoch 129/150
# 9013/9013 [==============================] - 2s 255us/sample - loss: 0.0130 - sparse_categorical_accuracy: 0.9955 - val_loss: 4.5116 - val_sparse_categorical_accuracy: 0.4909
# Epoch 130/150
# 9013/9013 [==============================] - 2s 200us/sample - loss: 0.0179 - sparse_categorical_accuracy: 0.9941 - val_loss: 4.5591 - val_sparse_categorical_accuracy: 0.5002
# Epoch 131/150
# 9013/9013 [==============================] - 2s 200us/sample - loss: 0.0287 - sparse_categorical_accuracy: 0.9899 - val_loss: 3.8282 - val_sparse_categorical_accuracy: 0.5087
# Epoch 132/150
# 9013/9013 [==============================] - 2s 251us/sample - loss: 0.0147 - sparse_categorical_accuracy: 0.9956 - val_loss: 4.3444 - val_sparse_categorical_accuracy: 0.5229
# Epoch 133/150
# 9013/9013 [==============================] - 2s 219us/sample - loss: 0.0237 - sparse_categorical_accuracy: 0.9918 - val_loss: 3.9825 - val_sparse_categorical_accuracy: 0.5255
# Epoch 134/150
# 9013/9013 [==============================] - 2s 207us/sample - loss: 0.0189 - sparse_categorical_accuracy: 0.9939 - val_loss: 3.1269 - val_sparse_categorical_accuracy: 0.5024
# Epoch 135/150
# 9013/9013 [==============================] - 2s 241us/sample - loss: 0.0175 - sparse_categorical_accuracy: 0.9939 - val_loss: 4.3671 - val_sparse_categorical_accuracy: 0.5118
# Epoch 136/150
# 9013/9013 [==============================] - 2s 204us/sample - loss: 0.0122 - sparse_categorical_accuracy: 0.9958 - val_loss: 4.2772 - val_sparse_categorical_accuracy: 0.5051
# Epoch 137/150
# 9013/9013 [==============================] - 2s 204us/sample - loss: 0.0185 - sparse_categorical_accuracy: 0.9923 - val_loss: 4.1850 - val_sparse_categorical_accuracy: 0.5016
# Epoch 138/150
# 9013/9013 [==============================] - 2s 257us/sample - loss: 0.0138 - sparse_categorical_accuracy: 0.9952 - val_loss: 4.7170 - val_sparse_categorical_accuracy: 0.5064
# Epoch 139/150
# 9013/9013 [==============================] - 2s 211us/sample - loss: 0.0166 - sparse_categorical_accuracy: 0.9952 - val_loss: 4.4833 - val_sparse_categorical_accuracy: 0.4931
# Epoch 140/150
# 9013/9013 [==============================] - 2s 243us/sample - loss: 0.0261 - sparse_categorical_accuracy: 0.9911 - val_loss: 3.5380 - val_sparse_categorical_accuracy: 0.4936
# Epoch 141/150
# 9013/9013 [==============================] - 2s 263us/sample - loss: 0.0149 - sparse_categorical_accuracy: 0.9941 - val_loss: 4.6057 - val_sparse_categorical_accuracy: 0.5047
# Epoch 142/150
# 9013/9013 [==============================] - 2s 209us/sample - loss: 0.0096 - sparse_categorical_accuracy: 0.9977 - val_loss: 4.4294 - val_sparse_categorical_accuracy: 0.5020
# Epoch 143/150
# 9013/9013 [==============================] - 2s 205us/sample - loss: 0.0154 - sparse_categorical_accuracy: 0.9950 - val_loss: 3.8259 - val_sparse_categorical_accuracy: 0.5064
# Epoch 144/150
# 9013/9013 [==============================] - 2s 260us/sample - loss: 0.0185 - sparse_categorical_accuracy: 0.9933 - val_loss: 4.4662 - val_sparse_categorical_accuracy: 0.4922
# Epoch 145/150
# 9013/9013 [==============================] - 2s 229us/sample - loss: 0.0150 - sparse_categorical_accuracy: 0.9949 - val_loss: 4.7304 - val_sparse_categorical_accuracy: 0.5122
# Epoch 146/150
# 9013/9013 [==============================] - 2s 204us/sample - loss: 0.0180 - sparse_categorical_accuracy: 0.9945 - val_loss: 4.4567 - val_sparse_categorical_accuracy: 0.5011
# Epoch 147/150
# 9013/9013 [==============================] - 2s 257us/sample - loss: 0.0117 - sparse_categorical_accuracy: 0.9957 - val_loss: 4.3679 - val_sparse_categorical_accuracy: 0.5126
# Epoch 148/150
# 9013/9013 [==============================] - 2s 215us/sample - loss: 0.0224 - sparse_categorical_accuracy: 0.9932 - val_loss: 3.8563 - val_sparse_categorical_accuracy: 0.4922
# Epoch 149/150
# 9013/9013 [==============================] - 2s 209us/sample - loss: 0.0059 - sparse_categorical_accuracy: 0.9981 - val_loss: 4.9285 - val_sparse_categorical_accuracy: 0.4953
# Epoch 150/150
# 9013/9013 [==============================] - 2s 248us/sample - loss: 0.0160 - sparse_categorical_accuracy: 0.9955 - val_loss: 4.1406 - val_sparse_categorical_accuracy: 0.5060

# %%
values = model.predict(testx[:20])

# %%
print(np.argmax(values,axis=1))
# Out:
# [7 5 5 6 5 5 5 3 5 7 7 8 5 3 5 7 7 5 3 7]

# %%
testy[:20]
# Out:
# array([5., 7., 4., 7., 6., 5., 5., 9., 7., 7., 3., 6., 3., 8., 5., 6., 7.,
#        3., 4., 4.])

# %%
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

pyplot.plot(history.history['sparse_categorical_accuracy'])
pyplot.plot(history.history['val_sparse_categorical_accuracy'])
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
model = tf.keras.Sequential()
model.add(keras.layers.Embedding(1000, output_dim=100, input_length=23))


# Add a LSTM layer with 128 internal units.
# model.add(keras.layers.GRU(32))
# model.add(keras.layers.Dense(16, activation='relu'))
# model.add(keras.layers.Dense(8, activation='relu'))
# model.add(keras.layers.Dense(4, activation='relu'))
# model.add(keras.layers.Dropout(0.2))
# model.add(keras.layers.Dense(1, activation='relu'))

# model.compile(loss='mean_squared_error',  
#               optimizer=keras.optimizers.SGD(lr=0.03,  nesterov=True),
#               metrics=['MAE'])

# history = model.fit(trainx, trainy,
#           validation_data=(testx, testy),
#           shuffle=True,
#           batch_size=128,
#           epochs=30);

input_array = np.random.randint(1000, size=(200, 23))

model.compile('rmsprop', 'mse')
output_array = model.predict(input_array)
print(output_array.shape)
# Out:
# (200, 23, 100)

# %% [markdown]
# Po tomto modeli sme sa rozhodli, že vytvoríme klasifikačnú rekurentnú neurónovú sieť(RNN). Model sme sa snažili priradiť do jednej zo 16 klasifikačných tried, pričom každá trieda symbolizovala počet gólov(v prípade, že mal byť výsledok 7 gólov a sieť ho odhadla správne, tak je najvyššia hodnota pravdepodobnost na indexe číslo 6 vo výslednom vektore).
#
# - Na trénovanie sme použili LSTM vrstvu, ktorú sme neskôr kvôli rýchlejšiemu trénovaniu nahradili GRU vrstvou.
# - Po tejto vrstve sme použili dense vrstvu so softmax aktiváciou, SGD optimizerom a sparse_categorical_crossentropy loss funkciou.
#
# Neskôr sme pridávali rôzne vrstvy, ktoré však väčšinou nemali veľký vplyv na výsledok. S nami otestovaných sietí boli najlepšie tieto:

# %% [markdown]
# Embedding(input_dim=64, output_dim=1)
# - GRU(32) ->
# - Dense(16, activation='relu') ->
# - Dense(16, activation='softmax')
#
# hyperparametre:
# - SGD(lr=0.01, momentum=0.65, nesterov=True)
# - loss='sparse_categorical_crossentropy'
# - metrics='sparse_categorical_accuracy'
# - batch_size=128
#  - epochs=25

# %%
model = tf.keras.Sequential()
# model.add(keras.layers.Embedding(64,  output_dim=100, input_length=25))

# Add a LSTM layer with 128 internal units.
# model.add(keras.layers.GRU(128))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(16, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',  
              optimizer=keras.optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.9, nesterov=False),
              metrics=['sparse_categorical_accuracy'])

history = model.fit(trainx, trainy,
          validation_data=(testx, testy),
          shuffle=True,
          batch_size=128,
          epochs=100);


values = model.predict(testx[:10])
# Out:
# Train on 8491 samples, validate on 1358 samples
# Epoch 1/100
# 8491/8491 [==============================] - 1s 93us/sample - loss: 2.2521 - sparse_categorical_accuracy: 0.2231 - val_loss: 2.2149 - val_sparse_categorical_accuracy: 0.1642
# Epoch 2/100
# 8491/8491 [==============================] - 0s 27us/sample - loss: 2.1502 - sparse_categorical_accuracy: 0.2451 - val_loss: 2.2081 - val_sparse_categorical_accuracy: 0.2172
# Epoch 3/100
# 8491/8491 [==============================] - 0s 33us/sample - loss: 2.1425 - sparse_categorical_accuracy: 0.2460 - val_loss: 2.2044 - val_sparse_categorical_accuracy: 0.2172
# Epoch 4/100
# 8491/8491 [==============================] - 1s 61us/sample - loss: 2.1354 - sparse_categorical_accuracy: 0.2489 - val_loss: 2.2026 - val_sparse_categorical_accuracy: 0.2172
# Epoch 5/100
# 8491/8491 [==============================] - 1s 60us/sample - loss: 2.1277 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.2158 - val_sparse_categorical_accuracy: 0.2172
# Epoch 6/100
# 8491/8491 [==============================] - 1s 62us/sample - loss: 2.1252 - sparse_categorical_accuracy: 0.2480 - val_loss: 2.2049 - val_sparse_categorical_accuracy: 0.2172
# Epoch 7/100
# 8491/8491 [==============================] - 1s 63us/sample - loss: 2.1265 - sparse_categorical_accuracy: 0.2490 - val_loss: 2.2187 - val_sparse_categorical_accuracy: 0.2172
# Epoch 8/100
# 8491/8491 [==============================] - 1s 64us/sample - loss: 2.1252 - sparse_categorical_accuracy: 0.2497 - val_loss: 2.2625 - val_sparse_categorical_accuracy: 0.2172
# Epoch 9/100
# 8491/8491 [==============================] - 1s 81us/sample - loss: 2.1226 - sparse_categorical_accuracy: 0.2484 - val_loss: 2.2020 - val_sparse_categorical_accuracy: 0.2172
# Epoch 10/100
# 8491/8491 [==============================] - 1s 66us/sample - loss: 2.1246 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.1933 - val_sparse_categorical_accuracy: 0.2172
# Epoch 11/100
# 8491/8491 [==============================] - 1s 62us/sample - loss: 2.1215 - sparse_categorical_accuracy: 0.2486 - val_loss: 2.1959 - val_sparse_categorical_accuracy: 0.2172
# Epoch 12/100
# 8491/8491 [==============================] - 1s 66us/sample - loss: 2.1198 - sparse_categorical_accuracy: 0.2491 - val_loss: 2.2225 - val_sparse_categorical_accuracy: 0.2172
# Epoch 13/100
# 8491/8491 [==============================] - 1s 66us/sample - loss: 2.1197 - sparse_categorical_accuracy: 0.2491 - val_loss: 2.2062 - val_sparse_categorical_accuracy: 0.2172
# Epoch 14/100
# 8491/8491 [==============================] - 1s 66us/sample - loss: 2.1197 - sparse_categorical_accuracy: 0.2486 - val_loss: 2.1919 - val_sparse_categorical_accuracy: 0.2172
# Epoch 15/100
# 8491/8491 [==============================] - 1s 82us/sample - loss: 2.1209 - sparse_categorical_accuracy: 0.2486 - val_loss: 2.2110 - val_sparse_categorical_accuracy: 0.2172
# Epoch 16/100
# 8491/8491 [==============================] - 1s 68us/sample - loss: 2.1197 - sparse_categorical_accuracy: 0.2485 - val_loss: 2.1987 - val_sparse_categorical_accuracy: 0.2172
# Epoch 17/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1168 - sparse_categorical_accuracy: 0.2498 - val_loss: 2.2009 - val_sparse_categorical_accuracy: 0.2172
# Epoch 18/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1179 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1958 - val_sparse_categorical_accuracy: 0.2165
# Epoch 19/100
# 8491/8491 [==============================] - 1s 83us/sample - loss: 2.1166 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.2239 - val_sparse_categorical_accuracy: 0.2172
# Epoch 20/100
# 8491/8491 [==============================] - 1s 68us/sample - loss: 2.1177 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.2062 - val_sparse_categorical_accuracy: 0.2172
# Epoch 21/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1144 - sparse_categorical_accuracy: 0.2493 - val_loss: 2.2098 - val_sparse_categorical_accuracy: 0.2209
# Epoch 22/100
# 8491/8491 [==============================] - 1s 68us/sample - loss: 2.1147 - sparse_categorical_accuracy: 0.2480 - val_loss: 2.2130 - val_sparse_categorical_accuracy: 0.2172
# Epoch 23/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1175 - sparse_categorical_accuracy: 0.2490 - val_loss: 2.2023 - val_sparse_categorical_accuracy: 0.2172
# Epoch 24/100
# 8491/8491 [==============================] - 1s 70us/sample - loss: 2.1162 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.2213 - val_sparse_categorical_accuracy: 0.2172
# Epoch 25/100
# 8491/8491 [==============================] - 1s 68us/sample - loss: 2.1150 - sparse_categorical_accuracy: 0.2485 - val_loss: 2.2008 - val_sparse_categorical_accuracy: 0.2172
# Epoch 26/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1148 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.1913 - val_sparse_categorical_accuracy: 0.2172
# Epoch 27/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1135 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1941 - val_sparse_categorical_accuracy: 0.2172
# Epoch 28/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1118 - sparse_categorical_accuracy: 0.2504 - val_loss: 2.2193 - val_sparse_categorical_accuracy: 0.2143
# Epoch 29/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1145 - sparse_categorical_accuracy: 0.2481 - val_loss: 2.1985 - val_sparse_categorical_accuracy: 0.2172
# Epoch 30/100
# 8491/8491 [==============================] - 1s 84us/sample - loss: 2.1128 - sparse_categorical_accuracy: 0.2497 - val_loss: 2.2245 - val_sparse_categorical_accuracy: 0.2172
# Epoch 31/100
# 8491/8491 [==============================] - 1s 96us/sample - loss: 2.1132 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.2293 - val_sparse_categorical_accuracy: 0.2172
# Epoch 32/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1126 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.2042 - val_sparse_categorical_accuracy: 0.2180
# Epoch 33/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1100 - sparse_categorical_accuracy: 0.2487 - val_loss: 2.2118 - val_sparse_categorical_accuracy: 0.2113
# Epoch 34/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1108 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.1922 - val_sparse_categorical_accuracy: 0.2172
# Epoch 35/100
# 8491/8491 [==============================] - 1s 70us/sample - loss: 2.1101 - sparse_categorical_accuracy: 0.2498 - val_loss: 2.2008 - val_sparse_categorical_accuracy: 0.2172
# Epoch 36/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.1104 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1948 - val_sparse_categorical_accuracy: 0.2172
# Epoch 37/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.1105 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.1982 - val_sparse_categorical_accuracy: 0.2165
# Epoch 38/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.1097 - sparse_categorical_accuracy: 0.2494 - val_loss: 2.1957 - val_sparse_categorical_accuracy: 0.2172
# Epoch 39/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.1075 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.2129 - val_sparse_categorical_accuracy: 0.2172
# Epoch 40/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.1075 - sparse_categorical_accuracy: 0.2506 - val_loss: 2.2070 - val_sparse_categorical_accuracy: 0.2158
# Epoch 41/100
# 8491/8491 [==============================] - 1s 70us/sample - loss: 2.1088 - sparse_categorical_accuracy: 0.2489 - val_loss: 2.2000 - val_sparse_categorical_accuracy: 0.2216
# Epoch 42/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.1066 - sparse_categorical_accuracy: 0.2501 - val_loss: 2.2096 - val_sparse_categorical_accuracy: 0.2172
# Epoch 43/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.1040 - sparse_categorical_accuracy: 0.2473 - val_loss: 2.2168 - val_sparse_categorical_accuracy: 0.2187
# Epoch 44/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1051 - sparse_categorical_accuracy: 0.2498 - val_loss: 2.2349 - val_sparse_categorical_accuracy: 0.1885
# Epoch 45/100
# 8491/8491 [==============================] - 1s 60us/sample - loss: 2.1046 - sparse_categorical_accuracy: 0.2484 - val_loss: 2.2075 - val_sparse_categorical_accuracy: 0.2172
# Epoch 46/100
# 8491/8491 [==============================] - 1s 62us/sample - loss: 2.1035 - sparse_categorical_accuracy: 0.2472 - val_loss: 2.2030 - val_sparse_categorical_accuracy: 0.2187
# Epoch 47/100
# 8491/8491 [==============================] - 1s 62us/sample - loss: 2.1085 - sparse_categorical_accuracy: 0.2493 - val_loss: 2.2061 - val_sparse_categorical_accuracy: 0.2158
# Epoch 48/100
# 8491/8491 [==============================] - 1s 61us/sample - loss: 2.1047 - sparse_categorical_accuracy: 0.2532 - val_loss: 2.2491 - val_sparse_categorical_accuracy: 0.2084
# Epoch 49/100
# 8491/8491 [==============================] - 1s 62us/sample - loss: 2.1033 - sparse_categorical_accuracy: 0.2479 - val_loss: 2.2027 - val_sparse_categorical_accuracy: 0.2172
# Epoch 50/100
# 8491/8491 [==============================] - 1s 63us/sample - loss: 2.1017 - sparse_categorical_accuracy: 0.2512 - val_loss: 2.2016 - val_sparse_categorical_accuracy: 0.2143
# Epoch 51/100
# 8491/8491 [==============================] - 1s 61us/sample - loss: 2.1032 - sparse_categorical_accuracy: 0.2512 - val_loss: 2.2228 - val_sparse_categorical_accuracy: 0.2165
# Epoch 52/100
# 8491/8491 [==============================] - 1s 79us/sample - loss: 2.1003 - sparse_categorical_accuracy: 0.2523 - val_loss: 2.2136 - val_sparse_categorical_accuracy: 0.2172
# Epoch 53/100
# 8491/8491 [==============================] - 1s 90us/sample - loss: 2.1011 - sparse_categorical_accuracy: 0.2490 - val_loss: 2.2179 - val_sparse_categorical_accuracy: 0.2091
# Epoch 54/100
# 8491/8491 [==============================] - 1s 81us/sample - loss: 2.0985 - sparse_categorical_accuracy: 0.2491 - val_loss: 2.2197 - val_sparse_categorical_accuracy: 0.2172
# Epoch 55/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.0970 - sparse_categorical_accuracy: 0.2529 - val_loss: 2.2491 - val_sparse_categorical_accuracy: 0.1951
# Epoch 56/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.0991 - sparse_categorical_accuracy: 0.2533 - val_loss: 2.2215 - val_sparse_categorical_accuracy: 0.2121
# Epoch 57/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.1000 - sparse_categorical_accuracy: 0.2527 - val_loss: 2.2302 - val_sparse_categorical_accuracy: 0.2172
# Epoch 58/100
# 8491/8491 [==============================] - 1s 79us/sample - loss: 2.0941 - sparse_categorical_accuracy: 0.2560 - val_loss: 2.2086 - val_sparse_categorical_accuracy: 0.2158
# Epoch 59/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.0982 - sparse_categorical_accuracy: 0.2530 - val_loss: 2.2317 - val_sparse_categorical_accuracy: 0.2165
# Epoch 60/100
# 8491/8491 [==============================] - 1s 73us/sample - loss: 2.0952 - sparse_categorical_accuracy: 0.2534 - val_loss: 2.2219 - val_sparse_categorical_accuracy: 0.2187
# Epoch 61/100
# 8491/8491 [==============================] - 1s 74us/sample - loss: 2.0943 - sparse_categorical_accuracy: 0.2556 - val_loss: 2.2330 - val_sparse_categorical_accuracy: 0.2121
# Epoch 62/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0928 - sparse_categorical_accuracy: 0.2557 - val_loss: 2.2353 - val_sparse_categorical_accuracy: 0.2158
# Epoch 63/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.0926 - sparse_categorical_accuracy: 0.2540 - val_loss: 2.2322 - val_sparse_categorical_accuracy: 0.2150
# Epoch 64/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.0899 - sparse_categorical_accuracy: 0.2563 - val_loss: 2.2501 - val_sparse_categorical_accuracy: 0.2165
# Epoch 65/100
# 8491/8491 [==============================] - 1s 79us/sample - loss: 2.0930 - sparse_categorical_accuracy: 0.2547 - val_loss: 2.2120 - val_sparse_categorical_accuracy: 0.2209
# Epoch 66/100
# 8491/8491 [==============================] - 1s 77us/sample - loss: 2.0885 - sparse_categorical_accuracy: 0.2556 - val_loss: 2.2225 - val_sparse_categorical_accuracy: 0.2135
# Epoch 67/100
# 8491/8491 [==============================] - 1s 79us/sample - loss: 2.0875 - sparse_categorical_accuracy: 0.2563 - val_loss: 2.2849 - val_sparse_categorical_accuracy: 0.2128
# Epoch 68/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0863 - sparse_categorical_accuracy: 0.2512 - val_loss: 2.2232 - val_sparse_categorical_accuracy: 0.2158
# Epoch 69/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.0853 - sparse_categorical_accuracy: 0.2579 - val_loss: 2.2281 - val_sparse_categorical_accuracy: 0.2158
# Epoch 70/100
# 8491/8491 [==============================] - 1s 77us/sample - loss: 2.0853 - sparse_categorical_accuracy: 0.2534 - val_loss: 2.2823 - val_sparse_categorical_accuracy: 0.2047
# Epoch 71/100
# 8491/8491 [==============================] - 1s 81us/sample - loss: 2.0828 - sparse_categorical_accuracy: 0.2576 - val_loss: 2.2535 - val_sparse_categorical_accuracy: 0.1996
# Epoch 72/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0799 - sparse_categorical_accuracy: 0.2584 - val_loss: 2.2187 - val_sparse_categorical_accuracy: 0.2150
# Epoch 73/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.0773 - sparse_categorical_accuracy: 0.2576 - val_loss: 2.2480 - val_sparse_categorical_accuracy: 0.2158
# Epoch 74/100
# 8491/8491 [==============================] - 1s 78us/sample - loss: 2.0819 - sparse_categorical_accuracy: 0.2578 - val_loss: 2.2239 - val_sparse_categorical_accuracy: 0.2283
# Epoch 75/100
# 8491/8491 [==============================] - 1s 78us/sample - loss: 2.0777 - sparse_categorical_accuracy: 0.2565 - val_loss: 2.2668 - val_sparse_categorical_accuracy: 0.2158
# Epoch 76/100
# 8491/8491 [==============================] - 1s 79us/sample - loss: 2.0766 - sparse_categorical_accuracy: 0.2589 - val_loss: 2.2784 - val_sparse_categorical_accuracy: 0.1959
# Epoch 77/100
# 8491/8491 [==============================] - 1s 77us/sample - loss: 2.0770 - sparse_categorical_accuracy: 0.2569 - val_loss: 2.2953 - val_sparse_categorical_accuracy: 0.2106
# Epoch 78/100
# 8491/8491 [==============================] - 1s 78us/sample - loss: 2.0731 - sparse_categorical_accuracy: 0.2589 - val_loss: 2.2366 - val_sparse_categorical_accuracy: 0.2113
# Epoch 79/100
# 8491/8491 [==============================] - 1s 77us/sample - loss: 2.0697 - sparse_categorical_accuracy: 0.2611 - val_loss: 2.3387 - val_sparse_categorical_accuracy: 0.1951
# Epoch 80/100
# 8491/8491 [==============================] - 1s 98us/sample - loss: 2.0764 - sparse_categorical_accuracy: 0.2572 - val_loss: 2.2509 - val_sparse_categorical_accuracy: 0.2113
# Epoch 81/100
# 8491/8491 [==============================] - 1s 88us/sample - loss: 2.0718 - sparse_categorical_accuracy: 0.2593 - val_loss: 2.2397 - val_sparse_categorical_accuracy: 0.2143
# Epoch 82/100
# 8491/8491 [==============================] - 1s 82us/sample - loss: 2.0667 - sparse_categorical_accuracy: 0.2639 - val_loss: 2.2384 - val_sparse_categorical_accuracy: 0.2246
# Epoch 83/100
# 8491/8491 [==============================] - 1s 63us/sample - loss: 2.0691 - sparse_categorical_accuracy: 0.2644 - val_loss: 2.2617 - val_sparse_categorical_accuracy: 0.2106
# Epoch 84/100
# 8491/8491 [==============================] - 1s 67us/sample - loss: 2.0652 - sparse_categorical_accuracy: 0.2630 - val_loss: 2.2517 - val_sparse_categorical_accuracy: 0.2165
# Epoch 85/100
# 8491/8491 [==============================] - 1s 71us/sample - loss: 2.0655 - sparse_categorical_accuracy: 0.2640 - val_loss: 2.2395 - val_sparse_categorical_accuracy: 0.2158
# Epoch 86/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0640 - sparse_categorical_accuracy: 0.2620 - val_loss: 2.3046 - val_sparse_categorical_accuracy: 0.2135
# Epoch 87/100
# 8491/8491 [==============================] - 1s 68us/sample - loss: 2.0606 - sparse_categorical_accuracy: 0.2596 - val_loss: 2.2739 - val_sparse_categorical_accuracy: 0.2209
# Epoch 88/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.0627 - sparse_categorical_accuracy: 0.2603 - val_loss: 2.2634 - val_sparse_categorical_accuracy: 0.2128
# Epoch 89/100
# 8491/8491 [==============================] - 1s 76us/sample - loss: 2.0540 - sparse_categorical_accuracy: 0.2665 - val_loss: 2.2747 - val_sparse_categorical_accuracy: 0.2113
# Epoch 90/100
# 8491/8491 [==============================] - 1s 74us/sample - loss: 2.0629 - sparse_categorical_accuracy: 0.2615 - val_loss: 2.2834 - val_sparse_categorical_accuracy: 0.2216
# Epoch 91/100
# 8491/8491 [==============================] - 1s 73us/sample - loss: 2.0554 - sparse_categorical_accuracy: 0.2631 - val_loss: 2.2663 - val_sparse_categorical_accuracy: 0.2121
# Epoch 92/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.0523 - sparse_categorical_accuracy: 0.2649 - val_loss: 2.3181 - val_sparse_categorical_accuracy: 0.2158
# Epoch 93/100
# 8491/8491 [==============================] - 1s 72us/sample - loss: 2.0491 - sparse_categorical_accuracy: 0.2662 - val_loss: 2.3135 - val_sparse_categorical_accuracy: 0.2077
# Epoch 94/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.0524 - sparse_categorical_accuracy: 0.2648 - val_loss: 2.2534 - val_sparse_categorical_accuracy: 0.2180
# Epoch 95/100
# 8491/8491 [==============================] - 1s 69us/sample - loss: 2.0454 - sparse_categorical_accuracy: 0.2721 - val_loss: 2.3609 - val_sparse_categorical_accuracy: 0.1848
# Epoch 96/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0511 - sparse_categorical_accuracy: 0.2670 - val_loss: 2.2982 - val_sparse_categorical_accuracy: 0.2084
# Epoch 97/100
# 8491/8491 [==============================] - 1s 74us/sample - loss: 2.0484 - sparse_categorical_accuracy: 0.2678 - val_loss: 2.3712 - val_sparse_categorical_accuracy: 0.1878
# Epoch 98/100
# 8491/8491 [==============================] - 1s 78us/sample - loss: 2.0412 - sparse_categorical_accuracy: 0.2696 - val_loss: 2.3480 - val_sparse_categorical_accuracy: 0.1966
# Epoch 99/100
# 8491/8491 [==============================] - 1s 80us/sample - loss: 2.0408 - sparse_categorical_accuracy: 0.2716 - val_loss: 2.2932 - val_sparse_categorical_accuracy: 0.2084
# Epoch 100/100
# 8491/8491 [==============================] - 1s 75us/sample - loss: 2.0462 - sparse_categorical_accuracy: 0.2658 - val_loss: 2.3590 - val_sparse_categorical_accuracy: 0.2106

# %%
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

pyplot.plot(history.history['sparse_categorical_accuracy'])
pyplot.plot(history.history['val_sparse_categorical_accuracy'])
pyplot.ylabel('accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-83b761408c69> in <module>
# ----> 1 pyplot.plot(history.history['loss'])
#       2 pyplot.plot(history.history['val_loss'])
#       3 pyplot.ylabel('loss')
#       4 pyplot.xlabel('epoch')
#       5 pyplot.legend(['train', 'validation'], loc='upper right')
#
# NameError: name 'history' is not defined

# %% [markdown]
# Embedding(input_dim=64, output_dim=1)
# - GRU(32) ->
# - Dropout(0.2) ->
# - Dense(16, activation='softmax')
#
# Hyperparametre:
# - SGD(lr=0.001, decay=1e-6, momentum=0.7, nesterov=False),
# - loss='sparse_categorical_crossentropy'
# - metrics='sparse_categorical_accuracy'
# - batch_size=128
#  - epochs=30

# %%
model = tf.keras.Sequential()
model.add(keras.layers.Embedding(input_dim=64, output_dim=1))

# Add a LSTM layer with 128 internal units.
model.add(keras.layers.GRU(32))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(16, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',  
              optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.65, nesterov=True),
              metrics=['sparse_categorical_accuracy'])

history = model.fit(trainx, trainy,
          validation_data=(testx, testy),
          shuffle=True,
          batch_size=128,
          epochs=25);

values = model.predict(testx[:10])
# Out:
# Train on 8491 samples, validate on 1358 samples
# Epoch 1/25
# 8491/8491 [==============================] - 4s 424us/sample - loss: 2.6339 - sparse_categorical_accuracy: 0.2306 - val_loss: 2.5064 - val_sparse_categorical_accuracy: 0.2172
# Epoch 2/25
# 8491/8491 [==============================] - 1s 132us/sample - loss: 2.3809 - sparse_categorical_accuracy: 0.2434 - val_loss: 2.3233 - val_sparse_categorical_accuracy: 0.2172
# Epoch 3/25
# 8491/8491 [==============================] - 1s 118us/sample - loss: 2.2704 - sparse_categorical_accuracy: 0.2331 - val_loss: 2.2552 - val_sparse_categorical_accuracy: 0.2172
# Epoch 4/25
# 8491/8491 [==============================] - 1s 119us/sample - loss: 2.2167 - sparse_categorical_accuracy: 0.2342 - val_loss: 2.2258 - val_sparse_categorical_accuracy: 0.2172
# Epoch 5/25
# 8491/8491 [==============================] - 1s 121us/sample - loss: 2.1934 - sparse_categorical_accuracy: 0.2388 - val_loss: 2.2133 - val_sparse_categorical_accuracy: 0.2172
# Epoch 6/25
# 8491/8491 [==============================] - 1s 121us/sample - loss: 2.1803 - sparse_categorical_accuracy: 0.2432 - val_loss: 2.2077 - val_sparse_categorical_accuracy: 0.2172
# Epoch 7/25
# 8491/8491 [==============================] - 1s 134us/sample - loss: 2.1678 - sparse_categorical_accuracy: 0.2450 - val_loss: 2.2050 - val_sparse_categorical_accuracy: 0.2172
# Epoch 8/25
# 8491/8491 [==============================] - 1s 123us/sample - loss: 2.1647 - sparse_categorical_accuracy: 0.2436 - val_loss: 2.2029 - val_sparse_categorical_accuracy: 0.2172
# Epoch 9/25
# 8491/8491 [==============================] - 1s 121us/sample - loss: 2.1557 - sparse_categorical_accuracy: 0.2447 - val_loss: 2.2003 - val_sparse_categorical_accuracy: 0.2172
# Epoch 10/25
# 8491/8491 [==============================] - 1s 122us/sample - loss: 2.1563 - sparse_categorical_accuracy: 0.2472 - val_loss: 2.1979 - val_sparse_categorical_accuracy: 0.2172
# Epoch 11/25
# 8491/8491 [==============================] - 1s 133us/sample - loss: 2.1485 - sparse_categorical_accuracy: 0.2489 - val_loss: 2.1985 - val_sparse_categorical_accuracy: 0.2172
# Epoch 12/25
# 8491/8491 [==============================] - 1s 125us/sample - loss: 2.1493 - sparse_categorical_accuracy: 0.2486 - val_loss: 2.1975 - val_sparse_categorical_accuracy: 0.2172
# Epoch 13/25
# 8491/8491 [==============================] - 1s 139us/sample - loss: 2.1447 - sparse_categorical_accuracy: 0.2496 - val_loss: 2.1958 - val_sparse_categorical_accuracy: 0.2172
# Epoch 14/25
# 8491/8491 [==============================] - 1s 129us/sample - loss: 2.1413 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1971 - val_sparse_categorical_accuracy: 0.2172
# Epoch 15/25
# 8491/8491 [==============================] - 1s 130us/sample - loss: 2.1411 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1966 - val_sparse_categorical_accuracy: 0.2172
# Epoch 16/25
# 8491/8491 [==============================] - 1s 126us/sample - loss: 2.1353 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1948 - val_sparse_categorical_accuracy: 0.2172
# Epoch 17/25
# 8491/8491 [==============================] - 1s 127us/sample - loss: 2.1375 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1951 - val_sparse_categorical_accuracy: 0.2172
# Epoch 18/25
# 8491/8491 [==============================] - 1s 126us/sample - loss: 2.1344 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1975 - val_sparse_categorical_accuracy: 0.2172
# Epoch 19/25
# 8491/8491 [==============================] - 1s 128us/sample - loss: 2.1323 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1926 - val_sparse_categorical_accuracy: 0.2172
# Epoch 20/25
# 8491/8491 [==============================] - 1s 148us/sample - loss: 2.1296 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1957 - val_sparse_categorical_accuracy: 0.2172
# Epoch 21/25
# 8491/8491 [==============================] - 1s 125us/sample - loss: 2.1317 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1967 - val_sparse_categorical_accuracy: 0.2172
# Epoch 22/25
# 8491/8491 [==============================] - 1s 126us/sample - loss: 2.1337 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1957 - val_sparse_categorical_accuracy: 0.2172
# Epoch 23/25
# 8491/8491 [==============================] - 1s 126us/sample - loss: 2.1306 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1947 - val_sparse_categorical_accuracy: 0.2172
# Epoch 24/25
# 8491/8491 [==============================] - 1s 138us/sample - loss: 2.1307 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1960 - val_sparse_categorical_accuracy: 0.2172
# Epoch 25/25
# 8491/8491 [==============================] - 1s 127us/sample - loss: 2.1288 - sparse_categorical_accuracy: 0.2500 - val_loss: 2.1950 - val_sparse_categorical_accuracy: 0.2172

# %%
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

pyplot.plot(history.history['sparse_categorical_accuracy'])
pyplot.plot(history.history['val_sparse_categorical_accuracy'])
pyplot.ylabel('sparse_categorical_accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()

# %%
 # %tensorboard --logdir logs --bind_all
# Out:
#       <iframe id="tensorboard-frame-f8cbc5c607505c15" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f8cbc5c607505c15");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Sparse_categorical_accuracy bola v obidvoch modeloch na hranici **25%**, pričom aj pri zmene hyperparametrov a architektúry nebolo možné dosiahnuť vyššiu presnosť. Vyššie popísané architektúry boli použité z toho dôvodu, lebo dokázali najlepšie minimalizovať loss funkciu(**na hodnotu 2**), pričom pri ostatných architektúrach bola táto hodnota **2,7**.

# %%
import pandas as pd
import numpy as np

# %%
gameInput = pd.read_csv("nhl-game-data/game.csv").dropna().sort_values(by=['date_time_GMT'])
goalieInput = pd.read_csv("nhl-game-data/game_goalie_stats.csv")
skaterStatsInput = pd.read_csv("nhl-game-data/game_skater_stats.csv")
teamsStatsInput = pd.read_csv("nhl-game-data/game_teams_stats.csv")
teamInfoInput = pd.read_csv("nhl-game-data/team_info.csv")

# %%
gameInput.sort_values(by=['home_team_id','date_time_GMT'])
# Out:
#           game_id    season type   date_time         date_time_GMT  \
# 9779   2010020007  20102011    R  2010-10-08  2010-10-08T23:00:00Z
# 10380  2010020027  20102011    R  2010-10-11  2010-10-11T20:00:00Z
# 10540  2010020048  20102011    R  2010-10-15  2010-10-15T23:00:00Z
# 8866   2010020056  20102011    R  2010-10-16  2010-10-16T23:00:00Z
# 8903   2010020100  20102011    R  2010-10-23  2010-10-23T23:00:00Z
# ...           ...       ...  ...         ...                   ...
# 11184  2018021109  20182019    R  2019-03-17  2019-03-17T02:00:00Z
# 11259  2018021184  20182019    R  2019-03-27  2019-03-27T02:00:00Z
# 11291  2018021217  20182019    R  2019-03-31  2019-03-31T21:00:00Z
# 11313  2018021238  20182019    R  2019-04-03  2019-04-03T02:00:00Z
# 11343  2018021269  20182019    R  2019-04-07  2019-04-07T02:00:00Z
#
#        away_team_id  home_team_id  away_goals  home_goals       outcome  \
# 9779             25             1           4           3   away win OT
# ...

# %%
gameInput.sort_values(by=['away_team_id','date_time_GMT'])
# Out:
#           game_id    season type   date_time         date_time_GMT  \
# 10844  2010020017  20102011    R  2010-10-09  2010-10-09T23:00:00Z
# 10654  2010020036  20102011    R  2010-10-13  2010-10-13T23:00:00Z
# 9665   2010020086  20102011    R  2010-10-21  2010-10-21T23:30:00Z
# 9721   2010020112  20102011    R  2010-10-24  2010-10-24T23:00:00Z
# 10375  2010020128  20102011    R  2010-10-28  2010-10-28T02:30:00Z
# ...           ...       ...  ...         ...                   ...
# 11345  2018021270  20182019    R  2019-04-07  2019-04-07T02:30:00Z
# 11351  2018030181  20182019    P  2019-04-11  2019-04-11T02:30:00Z
# 11358  2018030182  20182019    P  2019-04-13  2019-04-13T02:30:00Z
# 11380  2018030185  20182019    P  2019-04-19  2019-04-19T02:00:00Z
# 11391  2018030187  20182019    P  2019-04-24  2019-04-24T02:00:00Z
#
#        away_team_id  home_team_id  away_goals  home_goals       outcome  \
# 10844             1            15           2           7  home win REG
# ...

# %%
gameInput.sort_values(by=['home_team_id','date_time_GMT'])
# Out:
#           game_id    season type   date_time             date_time_GMT  \
# 9779   2010020007  20102011    R  2010-10-08 2010-10-08 23:00:00+00:00
# 10380  2010020027  20102011    R  2010-10-11 2010-10-11 20:00:00+00:00
# 10540  2010020048  20102011    R  2010-10-15 2010-10-15 23:00:00+00:00
# 8866   2010020056  20102011    R  2010-10-16 2010-10-16 23:00:00+00:00
# 8903   2010020100  20102011    R  2010-10-23 2010-10-23 23:00:00+00:00
# ...           ...       ...  ...         ...                       ...
# 11184  2018021109  20182019    R  2019-03-17 2019-03-17 02:00:00+00:00
# 11259  2018021184  20182019    R  2019-03-27 2019-03-27 02:00:00+00:00
# 11291  2018021217  20182019    R  2019-03-31 2019-03-31 21:00:00+00:00
# 11313  2018021238  20182019    R  2019-04-03 2019-04-03 02:00:00+00:00
# 11343  2018021269  20182019    R  2019-04-07 2019-04-07 02:00:00+00:00
#
#        away_team_id  home_team_id  away_goals  home_goals       outcome  \
# ...

# %%
gameInput['date_time_GMT'] = pd.to_datetime(gameInput['date_time_GMT'], errors='coerce')

# %%
goalies = goalieInput.loc[:,['game_id','team_id','shots','saves']].groupby(['game_id','team_id']).sum().reset_index()
goalies['percentage'] = (goalies['saves'] / goalies['shots'])*100

# %%
gameInput = gameInput.sort_values(by=['game_id'])
gameInput
# Out:
#           game_id    season type   date_time             date_time_GMT  \
# 11078  2010020001  20102011    R  2010-10-07 2010-10-07 23:00:00+00:00
# 10725  2010020002  20102011    R  2010-10-07 2010-10-07 23:00:00+00:00
# 9625   2010020003  20102011    R  2010-10-07 2010-10-07 16:00:00+00:00
# 10256  2010020004  20102011    R  2010-10-08 2010-10-08 02:00:00+00:00
# 10673  2010020005  20102011    R  2010-10-08 2010-10-08 02:00:00+00:00
# ...           ...       ...  ...         ...                       ...
# 11429  2018030413  20182019    P  2019-06-02 2019-06-02 00:00:00+00:00
# 11430  2018030414  20182019    P  2019-06-04 2019-06-04 00:00:00+00:00
# 11431  2018030415  20182019    P  2019-06-07 2019-06-07 00:00:00+00:00
# 11432  2018030416  20182019    P  2019-06-10 2019-06-10 00:00:00+00:00
# 11433  2018030417  20182019    P  2019-06-13 2019-06-13 00:00:00+00:00
#
#        away_team_id  home_team_id  away_goals  home_goals       outcome  \
# ...

# %%
games = pd.DataFrame(columns=['game_id', 'season', 'time', 'home_scored', 'home_conceded', 'home_win','home_percentage', 'home_id', 'away_scored', 'away_conceded', 'away_win','away_percentage', 'away_id'])
for index, row in gameInput.iterrows():
    homeS = 0;
    homeC = 0;
    homeW = 0;
    awayS = 0;
    awayC = 0;
    awayW = 0;
    homePerc = 50;
    awayPerc = 50;
    if not (gameInput.loc[((gameInput['home_team_id'] == row['home_team_id']) & (gameInput['date_time_GMT'] < row['date_time_GMT']))].tail(10).empty):
        homeLast = gameInput.loc[((gameInput['home_team_id'] == row['home_team_id']) & (gameInput['date_time_GMT'] < row['date_time_GMT']))].tail(10)
        for index1, game in homeLast.iterrows():
            homeS += game['home_goals']
            homeC += game['away_goals']
            if(game['home_goals'] > game['away_goals']):
                homeW += 1
            if not goalies.loc[(goalies['game_id'] == row['game_id']) & (goalies['team_id'] == row['home_team_id'])].empty:
                homePerc = goalies.loc[(goalies['game_id'] == row['game_id']) & (goalies['team_id'] == row['home_team_id'])]
                homePerc = homePerc['percentage'].values[0]
    if not (gameInput.loc[((gameInput['away_team_id'] == row['away_team_id']) & (gameInput['date_time_GMT'] < row['date_time_GMT']))].tail(10).empty):
        awayLast = gameInput.loc[((gameInput['away_team_id'] == row['away_team_id']) & (gameInput['date_time_GMT'] < row['date_time_GMT']))].tail(10)
        for index1, game in awayLast.iterrows():
            awayS += game['away_goals']
            awayC += game['home_goals']
            if(game['away_goals'] > game['home_goals']):
                awayW += 1
            if not goalies.loc[(goalies['game_id'] == row['game_id']) & (goalies['team_id'] == row['away_team_id'])].empty:
                awayPerc = goalies.loc[(goalies['game_id'] == row['game_id']) & (goalies['team_id'] == row['away_team_id'])]
                awayPerc = awayPerc['percentage'].values[0]
    d = {'game_id': row['game_id'], 'season': row['season'], 'time': row['date_time_GMT'], 'home_scored': homeS, 'home_conceded': homeC, 'home_win': homeW, 'home_percentage': homePerc, 'home_id':row['home_team_id'], 'away_scored': awayS, 'away_conceded': awayC, 'away_win': awayW, 'away_percentage': awayPerc, 'away_id': row['away_team_id']}
    games.at[index, :] = d
#     print(row['game_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8d091a4fda07> in <module>
# ----> 1 games = pd.DataFrame(columns=['game_id', 'season', 'time', 'home_scored', 'home_conceded', 'home_win','home_percentage', 'home_id', 'away_scored', 'away_conceded', 'away_win','away_percentage', 'away_id'])
#       2 for index, row in gameInput.iterrows():
#       3     homeS = 0;
#       4     homeC = 0;
#       5     homeW = 0;
#
# NameError: name 'pd' is not defined

# %%
games.sort_values(by=['home_id', 'time']).head(20)
# Out:
#           game_id    season                       time home_scored  \
# 9779   2010020007  20102011  2010-10-08 23:00:00+00:00           0
# 10380  2010020027  20102011  2010-10-11 20:00:00+00:00           3
# 10540  2010020048  20102011  2010-10-15 23:00:00+00:00           4
# 8866   2010020056  20102011  2010-10-16 23:00:00+00:00           6
# 8903   2010020100  20102011  2010-10-23 23:00:00+00:00           7
# 9578   2010020179  20102011  2010-11-05 23:00:00+00:00           8
# 9129   2010020211  20102011  2010-11-11 00:00:00+00:00           8
# 10703  2010020227  20102011  2010-11-13 00:00:00+00:00          12
# 8738   2010020299  20102011  2010-11-23 00:00:00+00:00          16
# 10914  2010020313  20102011  2010-11-25 00:30:00+00:00          21
# 10005  2010020334  20102011  2010-11-27 18:00:00+00:00          23
# 10061  2010020367  20102011  2010-12-03 00:00:00+00:00          22
# 9882   2010020428  20102011  2010-12-12 00:00:00+00:00          22
# ...

# %%
games.to_csv('.\datasets\dataset41.csv', encoding='utf-8', index=False)
